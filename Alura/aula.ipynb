# %%
import numpy as np
import pandas as pd

# %% [markdown]
# arange - (inicio,fim,incremento)
# array - ([0,1,2,3]) ou ([[0,1,2,3],[2,3,4,4]]) ou (lista)
# ndim - Dimensões. 1D ou 2D ou 3D
# size - Número de informações
# shape - linhas,colunas
# T - Transposição do array
# array_equal(array1,array2) - Vê se dois arrays são iguais
# allclose(array1,array2,10) - Verifica se arrays são próximos. Se são mais distantes que 10, por exemplo
# randint - Gera número inteiro aleatório np.random.randint(low=40,high=100,size=100)
# uniform - Gera número float aleatório np.random.uniform(low=0.10,high=0.90,size=100)

# %%
dados = np.loadtxt('numpy-dados/apples_ts.csv',delimiter=',',usecols=np.arange(1,88)) #eliminou a primeiro coluna

# %%
dadost = dados.T

# %%
datas = dadost[:,0]
#pega todas as linhas e primeira coluna
#só que datas ficou 1.2023 mes.ano por isso faço assim:
datas = np.arange(1,88) #mês 1 até 87
precos = dadost[:,1:]

# %% [markdown]
# ## Gerando gráficos

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(datas,precos[:,0])
#pegando da primeira cidade
#plt.plt(x,y)

# %%
Moscow = precos[:,0]
Kaliningrad = precos[:,1]
Petersburg = precos[:,2]
Krasnodar = precos[:,3]
Ekaterinburg = precos[:,4]

# %%
Moscow2013 = Moscow[0:12] #vai até o valor 11, 12.2013
Moscow2014 = Moscow[12:24]
Moscow2015 = Moscow[24:36]
Moscow2016 = Moscow[36:48]

# %%
plt.plot(np.arange(1,13),Moscow2013)
plt.plot(np.arange(1,13),Moscow2014)
plt.plot(np.arange(1,13),Moscow2015)
plt.plot(np.arange(1,13),Moscow2016)
plt.legend(['2013','2014','2015','2016'])

# %%
sum(np.isnan(Kaliningrad))
# Out:
# 1

# %%
Kaliningrad[4] = np.mean([Kaliningrad[3], Kaliningrad[5]])

# %%
print(np.mean(Moscow))
print(np.mean(Kaliningrad))
# Out:
# 98.79781609195402
# 74.5506896551724

# %% [markdown]
# y=ax+b
# Equação da reta
# y - preço. valor da reta, nao valor real
# x - mês
# a - Coeficiente angular, da angulo da reta
# b - coeficiente linear, corta o y, eixo do preço

# %%
x = datas

# %%
y = 0.5*x + 80

# %%
plt.plot(datas,Moscow)
plt.plot(x,y)

# %%
coef = np.random.uniform(low=0.10,high=0.90,size=100)

# %%
b = 80
norma = np.array([])
for coeff in coef:
    norma = np.append(norma,np.linalg.norm(Moscow-(coeff*x+b)))

# %%
norma
# Out:
# array([108.11155399, 122.19818277, 138.92571693, 103.23996066,
#        114.95441212, 185.17984825, 128.64544063, 102.80512655,
#        102.03199714, 166.41009068, 214.55600872, 120.649881  ,
#        178.17446283, 145.04906516, 175.87794289, 115.0065214 ,
#        176.19754082, 130.37000857, 137.28333706, 102.07861249,
#        174.60787076, 128.81188078, 105.23152487, 101.81955781,
#        236.23531982, 233.00541266, 236.47803374, 104.15135318,
#        180.01461577, 206.17231224, 118.47839242, 173.70404046,
#        180.04583717, 105.60042354, 191.40062719, 108.84532625,
#        123.13948169, 141.63906678, 196.24600087, 140.60182138,
#        104.17392341, 103.93775564, 176.47377871, 141.86286837,
#        111.37270175, 185.10142926, 170.41247572, 140.29145893,
#        169.37950723, 199.6242031 , 156.88870962, 110.21676708,
#        118.55113876, 177.4235515 , 141.46372542, 117.44514608,
#        132.51713048, 149.81667836, 134.66352108, 132.19223561,
# ...
